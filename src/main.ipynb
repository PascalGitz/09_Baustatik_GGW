# %%
import numpy as np

a = np.array([1,1,2,])

b = np.array([])

b = np.append(b, a)

# %%
import sympy as sp

# %%
x = sp.symbols('x')

# %%
def numeric_error(expr):
    if expr.args[0] <= 0.01:
        return 0
    else:
        return expr

# %%
numeric_error(x*0.01)
# Out:
# 0

# %%
(x * 0.004).numeric_error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Pascal Gitz\OneDrive - Hochschule Luzern\01_HSLU_Assistent\09_Baustatik_GGW\src\main.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Pascal%20Gitz/OneDrive%20-%20Hochschule%20Luzern/01_HSLU_Assistent/09_Baustatik_GGW/src/main.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> (x * 0.004).numeric_error
#
# AttributeError: 'Mul' object has no attribute 'numeric_error'

# %%
np.round(0.03,1
# Out:
# 0

# %%
import actions as ac
import reactions as re
import structure as st


einwirkungen_kraefte = [ac.Force(-15,90, 1.5,0), ac.Force(+50, 90, 3,0), ac.Force(-104, 90, 7.4, 0), ac.Force(50, 0,10,0)]
einwirkungen_momente = [ac.Moment(10, 0,0)]
reaktionen_kraefte = [re.Force(90, 0, 0), re.Force(90, 10,0), re.Force(0,0,0)]

system_1 = st.System(actionforces=einwirkungen_kraefte, reactionforces=reaktionen_kraefte, actionmoments=einwirkungen_momente)
system_1.calculate_reaction_force()


st.Plot(system_1).plot_forces_and_moments()
# Out:
# Das System hat keine Auflagermomente
# 3

# %%
reaktionen_kraefte[0].magnitude
# Out:
# 5.79
